# %% [markdown]
# <a href="https://colab.research.google.com/github/safdarhayatawan/ATM-App/blob/main/session_16_pandas_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from lists

# %%
# string
country = ['India','Pakistan','USA','Nepal','Srilanka']

pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
# integers
runs = [13,24,56,78,100]

runs_ser = pd.Series(runs)

# %%
# custom index
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']

pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks,index=subjects,name='Nitish ke marks')
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Nitish ke marks, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks,name='nitish ke marks')
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: nitish ke marks, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
# size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'nitish ke marks'

# %%
# is_unique
marks_series.is_unique

pd.Series([1,1,2,3,4,5]).is_unique
# Out:
# False

# %%
# index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# ### Series using read_csv

# %%
# with one col
vk = pd.read_csv('/content/kohli_ipl.csv')
movies =pd.read_csv('/content/bollywood.csv')
# br = pd.read_csv('/content/batsman_runs_ipl.csv')
subs = pd.read_csv('/content/subs.csv')
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
# with 2 cols
vk = pd.read_csv('/content/ipl-matches.csv')
vk
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movies = pd.read_csv('/content/bollywood.csv')
movies
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-1900628a1104> in <cell line: 1>()
# ----> 1 movies = pd.read_csv('/content/bollywood.csv')
#       2 movies
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# ### Series methods

# %%
# head and tail
subs.head()
subs.tail()
# Out:
#      Subscribers gained
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172

# %%
vk.head(9)
# Out:
#    match_no  runs
# 0         1     1
# 1         2    23
# 2         3    13
# 3         4    12
# 4         5     1
# 5         6     9
# 6         7    34
# 7         8     0
# 8         9    21

# %%
vk.tail(10)
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample
mv.sample(3)
# Out:
#                              movie          lead
# 568                      PK (film)    Aamir Khan
# 1041              Meerabai Not Out   Anupam Kher
# 1251  Ek Khiladi Ek Haseena (film)  Fardeen Khan

# %%
# value_counts -> movies
movies.value_counts()
# Out:
# movie                     lead
# Andaaz                    Akshay Kumar        2
# Tanu Weds Manu: Returns   Kangana Ranaut      2
# Gabbar Is Back            Akshay Kumar        2
# 1920 (film)               Rajniesh Duggall    1
# Newton (film)             Rajkummar Rao       1
#                                              ..
# Ghayal: Once Again        Sunny Deol          1
# Ghanchakkar (film)        Vidya Balan         1
# Ghajini (2008 film)       Aamir Khan          1
# Genius (2018 Hindi film)  Utkarsh Sharma      1
# Zor Lagaa Ke...Haiya!     Meghan Jadhav       1
# Name: count, Length: 1497, dtype: int64

# %%
# sort_values -> inplace
# vk.sort_values(ascending=False).head(1).values[0]
# vk.sort_values(ascending=False).head(1).values[0]
vk.sort_values(by="runs", ascending=False).head(1).values[0]
# Out:
# array([128, 113])

# %%
vk.sort_values(by="runs",ascending=False)
# Out:
#      match_no  runs
# 127       128   113
# 125       126   109
# 122       123   108
# 163       164   100
# 119       120   100
# ..        ...   ...
# 92         93     0
# 210       211     0
# 129       130     0
# 7           8     0
# 134       135     0
#
# [215 rows x 2 columns]

# %%
# sort_index -> inplace -> movies
movies.sort_index(ascending=True,inplace=True)

# %%
movies
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: object

# %%
vk.sort_values(inplace=True)

# %%
vk
# Out:
# match_no
# 87       0
# 211      0
# 207      0
# 206      0
# 91       0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %% [markdown]
# ### Series Maths Methods

# %%
# count
vk.count()
# Out:
# 215

# %%
# sum -> product
subs.sum()
# Out:
# 49510

# %%
# mean -> median -> mode -> std -> var
subs.mean()
print(vk.median())
print(movies.mode())
print(subs.std())
print(vk.var())
# Out:
# 24.0
# 0    Akshay Kumar
# dtype: object
# 62.6750230372527
# 688.0024777222343

# %%
# min/max
subs.max()
# Out:
# 396

# %%
# describe
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# ### Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
# negative indexing
x[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-60055cb99cf0> in <module>
#       1 # negative indexing
# ----> 2 x[-1]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ...

# %%
movies.value_counts("lead").head(16).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
vk[1:5]
# Out:
#    match_no  runs
# 1         2    23
# 2         3    13
# 3         4    12
# 4         5     1

# %%
marks_series[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-14301c43e6a1> in <cell line: 1>()
# ----> 1 marks_series[-1]
#
# NameError: name 'marks_series' is not defined

# %%
# slicing
vk[5:16]
# Out:
#     match_no  runs
# 5          6     9
# 6          7    34
# 7          8     0
# 8          9    21
# 9         10     3
# 10        11    10
# 11        12    38
# 12        13     3
# 13        14    11
# 14        15    50
# 15        16     2

# %%
# negative slicing
vk[-5:]
# Out:
#      match_no  runs
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7

# %%
movies[10:20:5]
# Out:
#                 movie              lead
# 10             Amavas         Ali Asgar
# 15  Badla (2019 film)  Amitabh Bachchan

# %%
# fancy indexing
vk[[1,3,4,5]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-25d3c6698571> in <cell line: 2>()
#       1 # fancy indexing
# ----> 2 vk[[1,3,4,5]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
# indexing with labels -> fancy indexing
movies['2 States (2014 film)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2 States (2014 film)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-3e4d9850dcb4> in <cell line: 2>()
#       1 # indexing with labels -> fancy indexing
# ...

# %% [markdown]
# ### Editing Series

# %%
# using indexing
marks_series[1] = 100
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# Name: nitish ke marks, dtype: int64

# %%
# what if an index does not exist
marks_series['evs'] = 100

# %%
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# sst         90
# evs        100
# Name: nitish ke marks, dtype: int64

# %%
# slicing
runs_ser[2:4] = [100,100]
runs_ser
# Out:
# 0     13
# 1     24
# 2    100
# 3    100
# 4    100
# dtype: int64

# %%
# fancy indexing
runs_ser[[0,3,4]] = [0,0,0]
runs_ser
# Out:
# 0      0
# 1     24
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
# using index label
movies['2 States (2014 film)'] = 'Alia Bhatt'
movies
# Out:
#                                      movie              lead  \
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
#      2 States (2014 film)
# 0              Alia Bhatt
# 1              Alia Bhatt
# 2              Alia Bhatt
# 3              Alia Bhatt
# 4              Alia Bhatt
# ...                   ...
# 1495           Alia Bhatt
# ...

# %% [markdown]
# ### Copy and Views

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min
# print(len(subs))
# print(type(subs))
# print(dir(subs))
# print(sorted(subs))
print(movies.sort_values(by="movie"))
# print(min(subs))
# print(max(subs))
# Out:
#                          movie                lead 2 States (2014 film)
# 1022               1920 (film)    Rajniesh Duggall           Alia Bhatt
# 287               1920: London       Sharman Joshi           Alia Bhatt
# 725     1920: The Evil Returns         Vicky Ahuja           Alia Bhatt
# 1040          1971 (2007 film)      Manoj Bajpayee           Alia Bhatt
# 484       2 States (2014 film)        Arjun Kapoor           Alia Bhatt
# ...                        ...                 ...                  ...
# 603              Zindagi 50-50         Veena Malik           Alia Bhatt
# 780   Zindagi Na Milegi Dobara      Hrithik Roshan           Alia Bhatt
# 672          Zindagi Tere Naam  Mithun Chakraborty           Alia Bhatt
# 758                   Zokkomon     Darsheel Safary           Alia Bhatt
# 941      Zor Lagaa Ke...Haiya!       Meghan Jadhav           Alia Bhatt
#
# [1500 rows x 3 columns]

# %%
# type conversion
list(marks_series)
# Out:
# [67, 100, 89, 100, 90, 100]

# %%
dict(marks_series)
# Out:
# {'maths': 67,
#  'english': 100,
#  'science': 89,
#  'hindi': 100,
#  'sst': 90,
#  'evs': 100}

# %%
# membership operator

'2 States (2014 film)' in movies
# Out:
# False

# %%
'Shah Rukh Khan' in movies.values
# Out:
# True

# %%
movies
# Out:
#                                      movie              lead  \
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
#      2 States (2014 film)
# 0              Alia Bhatt
# 1              Alia Bhatt
# 2              Alia Bhatt
# 3              Alia Bhatt
# 4              Alia Bhatt
# ...                   ...
# 1495           Alia Bhatt
# ...

# %%
# looping
for i in movies.index:
  print(i)
# Out:
# Zor Lagaa Ke...Haiya!
# Zokkomon
# Zindagi Tere Naam
# Zindagi Na Milegi Dobara
# Zindagi 50-50
# Zindaggi Rocks
# Zinda (film)
# Zila Ghaziabad
# Zid (2014 film)
# Zero (2018 film)
# Zeher
# Zed Plus
# Zameer: The Fire Within
# Zameen (2003 film)
# Zamaanat
# Yuvvraaj
# Yuva
# Yun Hota Toh Kya Hota
# Youngistaan
# Yeh Saali Aashiqui
# Yeh Mera India
# Yeh Lamhe Judaai Ke
# Yeh Khula Aasmaan
# Yeh Jawaani Hai Deewani
# Yeh Hai India
# Yeh Hai Bakrapur
# Yeh Dooriyan
# Yeh Dil
# Yatra (2007 film)
# Yamla Pagla Deewana: Phir Se
# Yamla Pagla Deewana
# Yakeen (2005 film)
# Yadvi – The Dignified Princess
# Yaaram (2019 film)
# Ya Rab
# Xcuse Me
# Woodstock Villa
# Woh Lamhe...
# Why Cheat India
# What's Your Raashee?
# What the Fish
# Well Done Abba
# Welcome to Sajjanpur
# Welcome Back (film)
# Welcome 2 Karachi
# Welcome (2007 film)
# Wedding Pullav
# Wedding Anniversary
# Waris Shah: Ishq Daa Waaris
# War Chhod Na Yaar
# Waqt: The Race Against Time
# Wanted (2009 film)
# Wake Up Sid
# ...

# %%
# Arithmetic Operators(Broadcasting)
100 + marks_series
# Out:
# maths      167
# english    200
# science    189
# hindi      200
# sst        190
# evs        200
# Name: nitish ke marks, dtype: int64

# %%
# Relational Operators

vk >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# ### Boolean Indexing on Series

# %%
# Find no of 50's and 100's scored by kohli
vk[vk >= 50].size
# Out:
# 50

# %%
import sys
vk.astype('int16')
sys.getsizeof(vk.astype('int16'))
# Out:
# 1004

# %%
# Count number of day when I had more than 200 subs a dayvk[vk["column_name"].between(51, 89)]
vk[vk["runs"].between(51, 89)].count()
# Out:
# match_no    39
# runs        39
# dtype: int64

# %%
# find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: lead, dtype: int64

# %% [markdown]
# ### Plotting Graphs on Series

# %%
subs.plot()

# %%
movies.value_counts().head(20).plot(kind='pie')

# %% [markdown]
# ### Some Important Series Methods

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
import numpy as np
import pandas as pd

# %%
subs = pd.read_csv('/content/subs.csv',squeeze=True)
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no',squeeze=True)
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie',squeeze=True)
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
# astype
import sys
sys.getsizeof(vk)
# Out:
# 3584

# %%
sys.getsizeof(vk.astype('int16'))
# Out:
# 1004

# %%
# between
vk.notnull().sum()
# Out:
# match_no    215
# runs        215
# dtype: int64

# %%
# clip
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# drop_duplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 1    1
# 3    2
# 5    3
# 7    4
# dtype: int64

# %%
temp.duplicated().sum()
# Out:
# 4

# %%
vk.duplicated().sum()
# Out:
# 137

# %%
movies.drop_duplicates()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Sssshhh...                              Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                  Tanuja
# Right Here Right Now (film)                        Ankit
# Talaash: The Hunt Begins...                Rakhee Gulzar
# The Pink Mirror                          Edwin Fernandes
# Name: lead, Length: 566, dtype: object

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# 7

# %%
# isnull
temp.isnull().sum()
# Out:
# 3

# %%
# dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin
vk[(vk == 49) | (vk == 99)]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
vk[vk.isin([49,99])]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
# apply
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: object

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.apply(lambda x:'good day' if x > subs.mean() else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
subs.mean()
# Out:
# 135.64383561643837

# %%
# copy

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new = vk.head()

# %%
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new[1] = 1

# %%
new = vk.head().copy()

# %%
new[1] = 100

# %%
new
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
